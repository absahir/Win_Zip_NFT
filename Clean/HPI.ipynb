# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('GeoFRED_All-Transactions_House_Price_Index_by_County_Index_2000=100.csv')

# %%
df.head()
# Out:
#         Series ID       Region Name State  Region Code    2010    2011  \
# 0  ATNHPIUS45001A  Abbeville County    SC        45001  132.29  128.12
# 1  ATNHPIUS22001A     Acadia Parish    LA        22001  144.44  142.77
# 2  ATNHPIUS51001A   Accomack County    VA        51001  171.86  167.34
# 3  ATNHPIUS16001A        Ada County    ID        16001  124.83  110.20
# 4  ATNHPIUS29001A      Adair County    MO        29001  112.61  113.79
#
#      2012    2013    2014    2015    2016    2017    2018    2019    2020
# 0  123.05  123.16  130.71  131.96  133.75  142.15  152.61  152.99  165.44
# 1  144.42  149.83  153.58  154.92  157.71  160.82  162.84  168.98  170.25
# 2  163.35  162.22  160.17  163.32  163.24  168.20  165.83  171.98  182.96
# 3  115.45  129.05  142.79  152.52  165.94  184.58  209.58  233.07  254.81
# 4  116.24  116.75  118.19  117.48  119.61  121.36  127.29  128.14  128.20

# %%
df = df.set_index("State")
df
# Out:
#             Series ID       Region Name  Region Code    2010    2011    2012  \
# State
#  SC    ATNHPIUS45001A  Abbeville County        45001  132.29  128.12  123.05
#  LA    ATNHPIUS22001A     Acadia Parish        22001  144.44  142.77  144.42
#  VA    ATNHPIUS51001A   Accomack County        51001  171.86  167.34  163.35
#  ID    ATNHPIUS16001A        Ada County        16001  124.83  110.20  115.45
#  MO    ATNHPIUS29001A      Adair County        29001  112.61  113.79  116.24
# ...               ...               ...          ...     ...     ...     ...
#  VA    ATNHPIUS51199A       York County        51199  178.80  170.74  165.77
#  TX    ATNHPIUS48503A      Young County        48503  140.08  140.33  142.63
#  CA    ATNHPIUS06115A       Yuba County         6115  124.75  108.06  108.65
#  CO    ATNHPIUS08125A       Yuma County         8125  135.59  141.59  143.15
#  AZ    ATNHPIUS04027A       Yuma County         4027  135.22  122.02  118.83
#
# ...

# %%
df.loc[[" GA"], :]
# Out:
#             Series ID       Region Name  Region Code    2010    2011    2012  \
# State
#  GA    ATNHPIUS13001A    Appling County        13001  122.45  112.62  111.42
#  GA    ATNHPIUS13009A    Baldwin County        13009  130.75  121.33  121.77
#  GA    ATNHPIUS13011A      Banks County        13011  102.99  100.54   90.87
#  GA    ATNHPIUS13013A     Barrow County        13013   99.70   85.96   78.11
#  GA    ATNHPIUS13015A     Bartow County        13015  103.85   95.88   89.10
# ...               ...               ...          ...     ...     ...     ...
#  GA    ATNHPIUS13311A      White County        13311  114.22  105.26  101.52
#  GA    ATNHPIUS13313A  Whitfield County        13313  114.53  106.79  103.74
#  GA    ATNHPIUS13317A     Wilkes County        13317  112.60  112.05   97.98
#  GA    ATNHPIUS13319A  Wilkinson County        13319  112.19   99.70  107.58
#  GA    ATNHPIUS13321A      Worth County        13321  127.58  116.18  120.67
#
# ...

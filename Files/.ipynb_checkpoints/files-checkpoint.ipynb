# %%
import numpy as np
import pandas as pd

# %%
#data1 = pd.read_csv('GeoFRED_All-Transactions_House_Price_Index_by_County_Index_2000=100.csv', delimiter =",")
#data1.head()

# %%
  # reading two csv files
data1 = pd.read_csv('GeoFRED_All-Transactions_House_Price_Index_by_County_Index_2000=100.csv')
data2 = pd.read_csv('GeoFRED_Equifax_Subprime_Credit_Population_by_County_Percent.csv')
data3 = pd.read_csv('GeoFRED_Equifax_Subprime_Credit_Population_by_County_Percent.csv')
data4 = pd.read_csv('GeoFRED_Housing_Inventory__Active_Listing_Count_by_County_Level.csv')
data5 = pd.read_csv('GeoFRED_Per_Capita_Personal_Income_by_County_Dollars (1).csv')
data6 = pd.read_csv('GeoFRED_Unemployment_Rate_by_County_Percent (1).csv')

# %%
big_concat = pd.concat([data1.set_index('Region Code'),data2.set_index('Region Code'), data3.set_index("Region Code"), data4.set_index("Region Code"), data5.set_index("Region Code"), data6.set_index("Region Code")], axis=1, join='inner').reset_index()

# %%
big_concat.head()
# Out:
#    Region Code       Series ID    Region Name State    2010    2011    2012  \
# 0        22001  ATNHPIUS22001A  Acadia Parish    LA  144.44  142.77  144.42
# 1        16001  ATNHPIUS16001A     Ada County    ID  124.83  110.20  115.45
# 2        42001  ATNHPIUS42001A   Adams County    PA  149.71  141.61  136.11
# 3         8001  ATNHPIUS08001A   Adams County    CO  100.37   96.17   99.10
# 4        17001  ATNHPIUS17001A   Adams County    IL  130.80  131.11  133.08
#
#      2013    2014    2015  ...  2018 Q4  2019 Q1  2019 Q2  2019 Q3  2019 Q4  \
# 0  149.83  153.58  154.92  ...      4.8      5.0      4.9      5.5      5.1
# 1  129.05  142.79  152.52  ...      2.3      2.9      2.2      2.3      2.2
# 2  135.26  133.85  138.33  ...      3.0      3.6      3.1      3.6      3.2
# 3  107.68  123.21  140.02  ...      3.1      3.4      2.7      2.7      2.5
# 4  134.32  138.27  142.12  ...      3.9      4.2      3.0      3.1      2.8
#
#   2020 Q1 2020 Q2 2020 Q3  2020 Q4  2021 Q1
# 0     5.3     9.8     7.8      6.4      6.1
# 1     2.5     9.5     5.6      4.1      3.8
# 2     3.8    12.8     7.2      4.3      5.4
# 3     3.9    12.6     8.1      7.6      7.6
# 4     3.0    11.3     6.6      4.6      4.8
#
# [5 rows x 187 columns]

# %%
big_concat.columns
# Out:
# Index(['Series ID', 'Region Name', 'State', 'Series ID', 'Region Name',
#        'State', '2011 Q1', '2011 Q2', '2011 Q3', '2011 Q4',
#        ...
#        '2018 Q4', '2019 Q1', '2019 Q2', '2019 Q3', '2019 Q4', '2020 Q1',
#        '2020 Q2', '2020 Q3', '2020 Q4', '2021 Q1'],
#       dtype='object', length=126)

# %%
big_concat['State'].iloc[:,0]
#big_concat = big_concat.loc[:, big_concat.columns.duplicated()]
# Out:
# 0       LA
# 1       ID
# 2       PA
# 3       CO
# 4       IL
#       ...
# 970     ME
# 971     PA
# 972     SC
# 973     CA
# 974     AZ
# Name: State, Length: 975, dtype: object

# %%
big_concat.index.is_unique
# Out:
# True

# %%
# Filter all rows for which the player's
# age is greater than or equal to 25
state_filtered = big_concat[big_concat['State'].iloc[:,0] == " GA"]
  
# Print the new dataframe
state_filtered.head(15)
# Out:
#      Region Code       Series ID      Region Name State    2010    2011  \
# 36         13013  ATNHPIUS13013A    Barrow County    GA   99.70   85.96
# 39         13015  ATNHPIUS13015A    Bartow County    GA  103.85   95.88

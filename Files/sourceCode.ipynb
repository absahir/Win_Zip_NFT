# %%
#import all the neccesary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_public_school = pd.read_csv("../Files/Public_Schools.csv")

# %% [markdown]
# ## # reading two csv files
# data1 = pd.read_csv('../Clean/Equifax_Subprime.csv')
# data1 = pd.read_csv('GeoFRED_Equifax_Subprime_Credit_Population_by_County_Percent.csv')
# data3 = pd.read_csv('GeoFRED_Equifax_Subprime_Credit_Population_by_County_Percent.csv')
# data4 = pd.read_csv('GeoFRED_Housing_Inventory__Active_Listing_Count_by_County_Level.csv')
# data5 = pd.read_csv('GeoFRED_Per_Capita_Personal_Income_by_County_Dollars (1).csv')
# data6 = pd.read_csv('GeoFRED_Unemployment_Rate_by_County_Percent (1).csv')

# %%
df_public_school.head()
# Out:
#             X          Y  OBJECTID        NCESID  \
# 0  -88.431010  42.465566         1  170330000017
# 1  -80.911501  35.231909         2  370297001287
# 2  -86.062430  39.489753         3  180369000584
# 3 -111.687306  33.242888         4   40187003479
# 4 -111.683768  33.222170         5   40187003483
#
#                                             NAME             ADDRESS  \
# 0                       ALDEN-HEBRON HIGH SCHOOL    9604 ILLINOIS ST
# 1                         WESTERLY HILLS ACADEMY     4420 DENVER AVE
# 2                    NORTHWOOD ELEMENTARY SCHOOL  965 GRIZZLY CUB DR
# 3  DR. GARY AND ANNETTE AUXIER ELEMENTARY SCHOOL  22700 S. POWER RD.
# 4                DR. CAMILLE CASTEEL HIGH SCHOOL  24901 S. POWER RD.
#
#           CITY STATE    ZIP           ZIP4  ...     VAL_METHOD  \
# 0       HEBRON    IL  60034           9618  ...  IMAGERY/OTHER
# 1    CHARLOTTE    NC  28208           3699  ...  IMAGERY/OTHER
# ...

# %%
df_public_school.tail()
# Out:
#                  X          Y  OBJECTID        NCESID  \
# 102329  -96.582510  45.421397    102330  270015003019
# 102330  -92.680915  38.131828    102331  290699000174
# 102331  -76.464870  37.085021    102332  510264001238
# 102332  -81.065487  38.006724    102333  540030000182
# 102333 -120.911496  39.933983    102334   69110211706
#
#                                    NAME             ADDRESS          CITY  \
# 102329            LISMORE COLONY SCHOOL  80391 COUNTY RD 60       CLINTON
# 102330                OSAGE BEACH ELEM.   1241 NICHOLS ROAD   OSAGE BEACH
# 102331  POINT OPTION ALTERNATIVE SCHOOL   813 DILIGENCE DR.  NEWPORT NEWS
# 102332              GATEWOOD ELEMENTARY  5094 GATEWOOD ROAD  FAYETTEVILLE
# 102333        PLUMAS COUNTY OPPORTUNITY    1446 E. MAIN ST.        QUINCY
#
#        STATE    ZIP           ZIP4  ...     VAL_METHOD             VAL_DATE  \
# 102329    MN  56225            361  ...  IMAGERY/OTHER  2019/10/01 00:00:00
# ...

# %%
df_public_school.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102334 entries, 0 to 102333
# Data columns (total 33 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   X           102334 non-null  float64
#  1   Y           102334 non-null  float64
#  2   OBJECTID    102334 non-null  int64
#  3   NCESID      102334 non-null  int64
#  4   NAME        102334 non-null  object
#  5   ADDRESS     102331 non-null  object
#  6   CITY        102334 non-null  object
#  7   STATE       102334 non-null  object
#  8   ZIP         102334 non-null  int64
#  9   ZIP4        102334 non-null  object
#  10  TELEPHONE   102334 non-null  object
#  11  TYPE        102334 non-null  int64
#  12  STATUS      102334 non-null  int64
#  13  POPULATION  102334 non-null  int64
#  14  COUNTY      102311 non-null  object
#  15  COUNTYFIPS  102334 non-null  int64
#  16  COUNTRY     102334 non-null  object
#  17  LATITUDE    102334 non-null  float64
# ...

# %%
df_public_school.isnull().sum()
# Out:
# X              0
# Y              0
# OBJECTID       0
# NCESID         0
# NAME           0
# ADDRESS        3
# CITY           0
# STATE          0
# ZIP            0
# ZIP4           0
# TELEPHONE      0
# TYPE           0
# STATUS         0
# POPULATION     0
# COUNTY        23
# COUNTYFIPS     0
# COUNTRY        0
# LATITUDE       0
# LONGITUDE      0
# NAICS_CODE     0
# NAICS_DESC     0
# SOURCE         0
# SOURCEDATE     0
# VAL_METHOD     0
# VAL_DATE       0
# WEBSITE        0
# LEVEL_         0
# ENROLLMENT     0
# ST_GRADE       0
# END_GRADE      0
# DISTRICTID     0
# FT_TEACHER     0
# SHELTER_ID     0
# dtype: int64

# %%
# Analyse the missing values
sns.heatmap(df_public_school.isnull())
# Out:
# <AxesSubplot:>

# %%
# What all data we need to viz.
# What are the target/dependent variables

# %%
df_public_school['STATE'].value_counts()
# Out:
# CA    10442
# TX     9467
# NY     4847
# FL     4464
# IL     4295
# MI     3817
# OH     3670
# PA     3046
# NC     2707
# MN     2627
# NJ     2616
# AZ     2492
# WA     2472
# MO     2444
# GA     2327
# WI     2305
# VA     2159
# IN     1944
# CO     1920
# MA     1867
# OK     1827
# TN     1789
# KY     1557
# AL     1486
# MD     1429
# LA     1402
# IA     1345
# KS     1333
# PR     1282
# SC     1278
# OR     1255
# CT     1253
# NE     1119
# AR     1109
# MS     1087
# UT     1076
# NM      934
# MT      829
# ID      761
# WV      746
# NV      741
# SD      724
# ME      622
# ND      550
# AK      513
# NH      497
# WY      378
# RI      319
# VT      312
# HI      294
# DE      235
# DC      227
# GU       41
# VI       28
# AS       28
# Name: STATE, dtype: int64

# %%
df_public_school['COUNTY'].value_counts()
# Out:
# LOS ANGELES    2295
# COOK           1415
# MARICOPA       1274
# HARRIS         1157
# ORANGE         1082
#                ...
# MOTLEY            1
# EMPORIA           1
# TALIAFERRO        1
# GLASCOCK          1
# ST. JOHN          1
# Name: COUNTY, Length: 1911, dtype: int64

# %%
df_public_school['COUNTY'].isnull().sum()
# Out:
# 23

# %%
  # reading two csv files
data1 = pd.read_csv("../Files/GeoFRED_All-Transactions_House_Price_Index_by_County_Index_2000=100.csv")
data2 = pd.read_csv("../Files/GeoFRED_Equifax_Subprime_Credit_Population_by_County_Percent.csv")
data3 = pd.read_csv("../Files/GeoFRED_Gross_Domestic_Product__All_Industries_by_County_Percent_Change_from_Year_Ago.csv")
data4 = pd.read_csv("../Files/GeoFRED_Housing_Inventory__Active_Listing_Count_by_County_Level.csv")
data5 = pd.read_csv("../Files/GeoFRED_Per_Capita_Personal_Income_by_County_Dollars (1).csv")
data6 = pd.read_csv("../Files/GeoFRED_Unemployment_Rate_by_County_Percent (1).csv")
data7 = pd.read_csv("../Files/zillow_data.csv")

# %%
data1.info()
data2.info()
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2395 entries, 0 to 2394
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Series ID    2395 non-null   object
#  1   Region Name  2395 non-null   object
#  2   State        2395 non-null   object
#  3   Region Code  2395 non-null   int64
#  4   2010         2395 non-null   float64
#  5   2011         2395 non-null   float64
#  6   2012         2395 non-null   float64
#  7   2013         2395 non-null   float64
#  8   2014         2394 non-null   float64
#  9   2015         2395 non-null   float64
#  10  2016         2393 non-null   float64
#  11  2017         2389 non-null   float64
#  12  2018         2384 non-null   float64
#  13  2019         2378 non-null   float64
#  14  2020         2383 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 280.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3138 entries, 0 to 3137
# ...

# %%
df_GeoFRED_Unemployment_Rate_by_County_Percent = pd.read_csv("../Files/GeoFRED_Unemployment_Rate_by_County_Percent(1).csv")

# %%
df_GeoFRED_Unemployment_Rate_by_County_Percent .head()

# %%
df_public_school = pd.read_csv("../Files/Public_Schools.csv")

# %%
data1.isnull().sum()
# Out:
# Series ID       0
# Region Name     0
# State           0
# Region Code     0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            1
# 2015            0
# 2016            2
# 2017            6
# 2018           11
# 2019           17
# 2020           12
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Series ID      0
# Region Name    0
# State          0
# Region Code    0
# 2011 Q1        1
# 2011 Q2        3
# 2011 Q3        3
# 2011 Q4        3
# 2012 Q1        4
# 2012 Q2        4
# 2012 Q3        3
# 2012 Q4        2
# 2013 Q1        4
# 2013 Q2        5
# 2013 Q3        4
# 2013 Q4        3
# 2014 Q1        3
# 2014 Q2        3
# 2014 Q3        1
# 2014 Q4        1
# 2015 Q1        1
# 2015 Q2        2
# 2015 Q3        1
# 2015 Q4        1
# 2016 Q1        3
# 2016 Q2        4
# 2016 Q3        3
# 2016 Q4        3
# 2017 Q1        4
# 2017 Q2        4
# 2017 Q3        4
# 2017 Q4        4
# 2018 Q1        4
# 2018 Q2        3
# 2018 Q3        3
# 2018 Q4        4
# 2019 Q1        4
# 2019 Q2        5
# 2019 Q3        4
# 2019 Q4        3
# 2020 Q1        4
# 2020 Q2        4
# 2020 Q3        4
# 2020 Q4        4
# 2021 Q1        3
# dtype: int64

# %%
data3.isnull().sum()
# Out:
# Series ID      0
# Region Name    0
# State          0
# Region Code    0
# 2009           0
# 2010           0
# 2011           0
# 2012           0
# 2013           0
# 2014           0
# 2015           0
# 2016           0
# 2017           0
# 2018           0
# 2019           0
# dtype: int64

# %%
data4.isnull().sum()
# Out:
# Series ID      0
# Region Name    0
# State          0
# Region Code    0
# 2016 Q3        0
# 2016 Q4        0
# 2017 Q1        0
# 2017 Q2        0
# 2017 Q3        0
# 2017 Q4        0
# 2018 Q1        0
# 2018 Q2        0
# 2018 Q3        0
# 2018 Q4        0
# 2019 Q1        0
# 2019 Q2        0
# 2019 Q3        0
# 2019 Q4        0
# 2020 Q1        0
# 2020 Q2        0
# 2020 Q3        0
# 2020 Q4        0
# 2021 Q1        0
# dtype: int64

# %%
data5.isnull().sum()
# Out:
# Series ID      0
# Region Name    0
# State          0
# Region Code    0
# 2009           0
# 2010           0
# 2011           0
# 2012           0
# 2013           0
# 2014           1
# 2015           1
# 2016           1
# 2017           1
# 2018           1
# 2019           1
# dtype: int64

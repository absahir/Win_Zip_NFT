# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
filepath = Path('Files/CountyMortgagesPercent-30-89DaysLate-thru-2020-09.csv')
D1 = pd.read_csv(filepath)
filepath_2 = Path('Files/GeoFRED_All-Transactions_House_Price_Index_by_County_Index_2000=100.csv')
D2 = pd.read_csv(filepath_2)
filepath_3 = Path('Files/GeoFRED_Equifax_Subprime_Credit_Population_by_County_Percent.csv')
D3 = pd.read_csv(filepath_3)
filepath_4 = Path('Files/GeoFRED_Gross_Domestic_Product__All_Industries_by_County_Percent_Change_from_Year_Ago.csv')
D4 = pd.read_csv(filepath_4)
filepath_5 = Path('Files/GeoFRED_Housing_Inventory__Active_Listing_Count_by_County_Level.csv')
D5 = pd.read_csv(filepath_5)
filepath_6 = Path('Files/GeoFRED_Per_Capita_Personal_Income_by_County_Dollars (1).csv')
D6 = pd.read_csv(filepath_6)
filepath_7 = Path('Files/GeoFRED_Unemployment_Rate_by_County_Percent (1).csv')
D7 = pd.read_csv(filepath_7)
filepath_8 = Path('Files/Public_Schools.csv')
D8 = pd.read_csv(filepath_8)
filepath_9 = Path('Files/zillow_data.csv')
D9 = pd.read_csv(filepath_9)

# %%
D1.head()
# Out:
#   RegionType State              Name FIPSCode  2008-01  2008-02  2008-03  \
# 0   National   NaN     United States    -----      3.5      3.2      3.1
# 1     County    AL    Baldwin County  '01003'      2.8      3.1      3.2
# 2     County    AL  Jefferson County  '01073'      5.1      4.6      4.5
# 3     County    AL        Lee County  '01081'      3.8      4.5      4.2
# 4     County    AL    Madison County  '01089'      3.5      3.3      3.3
#
#    2008-04  2008-05  2008-06  ...  2019-12  2020-01  2020-02  2020-03  \
# 0      3.1      3.2      3.2  ...      2.2      2.2      1.8      1.8
# 1      2.5      2.7      2.7  ...      2.5      2.7      1.7      1.7
# 2      4.9      4.9      5.0  ...      3.5      3.7      3.0      2.6
# 3      3.6      3.8      4.4  ...      2.6      2.7      2.0      2.3
# 4      3.0      3.3      3.2  ...      2.2      2.2      1.5      1.8
#
#    2020-04  2020-05  2020-06  2020-07  2020-08  2020-09
# ...

# %%
D2.head()
# Out:
#         Series ID       Region Name State  Region Code    2010    2011  \
# 0  ATNHPIUS45001A  Abbeville County    SC        45001  132.29  128.12
# 1  ATNHPIUS22001A     Acadia Parish    LA        22001  144.44  142.77
# 2  ATNHPIUS51001A   Accomack County    VA        51001  171.86  167.34
# 3  ATNHPIUS16001A        Ada County    ID        16001  124.83  110.20
# 4  ATNHPIUS29001A      Adair County    MO        29001  112.61  113.79
#
#      2012    2013    2014    2015    2016    2017    2018    2019    2020
# 0  123.05  123.16  130.71  131.96  133.75  142.15  152.61  152.99  165.44
# 1  144.42  149.83  153.58  154.92  157.71  160.82  162.84  168.98  170.25
# 2  163.35  162.22  160.17  163.32  163.24  168.20  165.83  171.98  182.96
# 3  115.45  129.05  142.79  152.52  165.94  184.58  209.58  233.07  254.81
# 4  116.24  116.75  118.19  117.48  119.61  121.36  127.29  128.14  128.20

# %%
D3.head()
# Out:
#             Series ID       Region Name State  Region Code    2011 Q1  \
# 0  EQFXSUBPRIME045001  Abbeville County    SC        45001  43.610548
# 1  EQFXSUBPRIME022001     Acadia Parish    LA        22001  41.034156
# 2  EQFXSUBPRIME051001   Accomack County    VA        51001  35.006878
# 3  EQFXSUBPRIME016001        Ada County    ID        16001  29.424043
# 4  EQFXSUBPRIME029001      Adair County    MO        29001  30.604534
#
#      2011 Q2    2011 Q3    2011 Q4    2012 Q1    2012 Q2  ...    2018 Q4  \
# 0  44.444444  44.914401  45.070423  44.929006  43.478261  ...  37.524366
# 1  41.257089  41.103711  40.851064  40.370019  40.238663  ...  37.182637
# 2  35.452661  36.105336  36.350975  36.000000  34.480337  ...  30.209036
# 3  29.096229  29.112694  29.083614  28.705259  28.611916  ...  21.172013
# 4  30.164766  30.345711  29.097840  28.751576  29.937107  ...  24.399038
#
#      2019 Q1    2019 Q2    2019 Q3    2019 Q4    2020 Q1    2020 Q2  \
# ...

# %%
D4.head()
# Out:
#      Series ID       Region Name State  Region Code  2009  2010  2011  2012  \
# 0  GDPALL45001  Abbeville County    SC        45001    -2     4     4     0
# 1  GDPALL22001     Acadia Parish    LA        22001    -3     6     0     6
# 2  GDPALL51001   Accomack County    VA        51001    35     4    -5     8
# 3  GDPALL16001        Ada County    ID        16001    -2     0     1     2
# 4  GDPALL19001      Adair County    IA        19001    -8     0    17    -1
#
#    2013  2014  2015  2016  2017  2018  2019
# 0     9     6    -6     5     4     3     7
# 1    -3     1    -5     0     3     2     4
# 2   -14   -13    -6    -8    -6     2     1
# 3     7     7     4     6     8     9     5
# 4    11    -2     8    -2     0    13    20

# %%
D5.head()
# Out:
#         Series ID    Region Name State  Region Code  2016 Q3  2016 Q4  \
# 0  ACTLISCOU22001  Acadia Parish    LA        22001      129      125
# 1  ACTLISCOU16001     Ada County    ID        16001     2364     2045
# 2  ACTLISCOU17001   Adams County    IL        17001      342      330
# 3  ACTLISCOU42001   Adams County    PA        42001      772      671
# 4   ACTLISCOU8001   Adams County    CO         8001      765      760
#
#    2017 Q1  2017 Q2  2017 Q3  2017 Q4  ...  2018 Q4  2019 Q1  2019 Q2  \
# 0      120      131      142      139  ...      183      170      161
# 1     1558     1889     2090     1886  ...     1863     1525     1630
# 2      300      328      310      313  ...      302      281      307
# 3      548      627      624      460  ...      360      304      365
# 4      528      693      905      711  ...     1169      891     1078
#
#    2019 Q3  2019 Q4  2020 Q1  2020 Q2  2020 Q3  2020 Q4  2021 Q1
# ...

# %%
D6.head()
# Out:
#    Series ID       Region Name State  Region Code   2009   2010   2011   2012  \
# 0  PCPI45001  Abbeville County    SC        45001  25703  26620  27685  27574
# 1  PCPI22001     Acadia Parish    LA        22001  31203  31659  32924  34539
# 2  PCPI51001   Accomack County    VA        51001  32690  33626  34053  35622
# 3  PCPI16001        Ada County    ID        16001  37782  38325  39654  41499
# 4  PCPI29001      Adair County    MO        29001  27821  27185  28485  28705
#
#     2013     2014     2015     2016     2017     2018     2019
# 0  28233  29554.0  30933.0  31821.0  32837.0  33758.0  35219.0
# 1  35960  36962.0  35446.0  33910.0  35161.0  37060.0  37786.0
# 2  36129  37338.0  38852.0  39232.0  40837.0  41826.0  42923.0
# 3  42937  45421.0  47629.0  48429.0  50894.0  53663.0  54896.0
# 4  29323  30212.0  31401.0  31671.0  31689.0  32398.0  33351.0

# %%
D7.head()
# Out:
#     Series ID       Region Name State  Region Code  2010 Q1  2010 Q2  2010 Q3  \
# 0  SCABBE1URN  Abbeville County    SC        45001     15.5     13.3     13.6
# 1  LAACAD0URN     Acadia Parish    LA        22001      7.0      6.8      7.0
# 2  VAACCO1URN   Accomack County    VA        51001      9.4      7.4      7.3
# 3  IDADAC1URN        Ada County    ID        16001      9.2      7.9      7.7
# 4  OKADAI1URN      Adair County    OK        40001     11.9      9.8      9.3
#
#    2010 Q4  2011 Q1  2011 Q2  ...  2018 Q4  2019 Q1  2019 Q2  2019 Q3  \
# 0     12.8     13.1     12.3  ...      3.7      4.0      3.1      2.9
# 1      6.6      6.7      6.4  ...      4.8      5.0      4.9      5.5
# 2      8.3      9.5      7.8  ...      3.4      4.6      3.1      3.0
# 3      7.8      8.2      7.1  ...      2.3      2.9      2.2      2.3
# 4      9.1      9.8      8.4  ...      3.9      4.4      3.9      3.7
#
#    2019 Q4  2020 Q1  2020 Q2  2020 Q3  2020 Q4  2021 Q1
# ...

# %%
D8.head()
# Out:
#             X          Y  OBJECTID        NCESID  \
# 0  -88.431010  42.465566         1  170330000017
# 1  -80.911501  35.231909         2  370297001287
# 2  -86.062430  39.489753         3  180369000584
# 3 -111.687306  33.242888         4   40187003479
# 4 -111.683768  33.222170         5   40187003483
#
#                                             NAME             ADDRESS  \
# 0                       ALDEN-HEBRON HIGH SCHOOL    9604 ILLINOIS ST
# 1                         WESTERLY HILLS ACADEMY     4420 DENVER AVE
# 2                    NORTHWOOD ELEMENTARY SCHOOL  965 GRIZZLY CUB DR
# 3  DR. GARY AND ANNETTE AUXIER ELEMENTARY SCHOOL  22700 S. POWER RD.
# 4                DR. CAMILLE CASTEEL HIGH SCHOOL  24901 S. POWER RD.
#
#           CITY STATE    ZIP           ZIP4  ...     VAL_METHOD  \
# 0       HEBRON    IL  60034           9618  ...  IMAGERY/OTHER
# 1    CHARLOTTE    NC  28208           3699  ...  IMAGERY/OTHER
# ...

# %%
D9.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     61639         0       10025        Zip        NY    NY  New York
# 1     84654         1       60657        Zip        IL    IL   Chicago
# 2     61637         2       10023        Zip        NY    NY  New York
# 3     91982         3       77494        Zip        TX    TX      Katy
# 4     84616         4       60614        Zip        IL    IL   Chicago
#
#                               Metro       CountyName  1/31/2000  ...  \
# 0       New York-Newark-Jersey City  New York County   327302.0  ...
# 1          Chicago-Naperville-Elgin      Cook County   314318.0  ...
# 2       New York-Newark-Jersey City  New York County   380271.0  ...
# 3  Houston-The Woodlands-Sugar Land    Harris County   223127.0  ...
# 4          Chicago-Naperville-Elgin      Cook County   407203.0  ...
#
#    7/31/2020  8/31/2020  9/30/2020  10/31/2020  11/30/2020  12/31/2020  \
# ...

# %%
Dataset = pd.concat([D1.set_index('Name'), D2.set_index('Region Name'), D3.set_index('Region Name'), 
                     D4.set_index('Region Name'), D5.set_index('Region Name'), D6.set_index('Region Name'),
                     D7.set_index('Region Name'), D8.set_index('CITY'), D9.set_index('CountyName')
                    ], axis=0).reset_index()

# %%
Dataset.head(20)
# Out:
#                      index RegionType State FIPSCode  2008-01  2008-02  \
# 0            United States   National   NaN    -----      3.5      3.2
# 1           Baldwin County     County    AL  '01003'      2.8      3.1
# 2         Jefferson County     County    AL  '01073'      5.1      4.6
# 3               Lee County     County    AL  '01081'      3.8      4.5
# 4           Madison County     County    AL  '01089'      3.5      3.3
# 5            Mobile County     County    AL  '01097'      5.0      4.4
# 6        Montgomery County     County    AL  '01101'      6.0      5.3
# 7            Shelby County     County    AL  '01117'      3.0      3.0
# 8        Tuscaloosa County     County    AL  '01125'      3.9      3.2
# 9   Anchorage Municipality     County    AK  '02020'      2.8      2.5
# 10         Maricopa County     County    AZ  '04013'      3.7      3.3
# 11           Mohave County     County    AZ  '04015'      2.4      2.5
# ...

# %%
Dataset.tail(20)
# Out:
#                        index RegionType State FIPSCode  2008-01  2008-02  \
# 149440   Anne Arundel County        Zip    MD      NaN      NaN      NaN
# 149441       Monmouth County        Zip    NJ      NaN      NaN      NaN
# 149442         Tulare County        Zip    CA      NaN      NaN      NaN
# 149443         Tulare County        Zip    CA      NaN      NaN      NaN
# 149444           Iowa County        Zip    IA      NaN      NaN      NaN
# 149445       New York County        Zip    NY      NaN      NaN      NaN
# 149446         Washoe County        Zip    NV      NaN      NaN      NaN
# 149447        Dunklin County        Zip    MO      NaN      NaN      NaN
# 149448        Yavapai County        Zip    AZ      NaN      NaN      NaN
# 149449          Clark County        Zip    NV      NaN      NaN      NaN
# 149450         Durham County        Zip    NC      NaN      NaN      NaN
# 149451       Sullivan County        Zip    IN      NaN      NaN      NaN
# ...

# %%
Dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149460 entries, 0 to 149459
# Columns: 510 entries, index to 4/30/2021
# dtypes: float64(485), object(25)
# memory usage: 581.5+ MB

# %%
Dataset.describe()
# Out:
#           2008-01     2008-02     2008-03     2008-04     2008-05     2008-06  \
# count  472.000000  472.000000  472.000000  472.000000  472.000000  472.000000
# mean     3.441525    3.149576    2.998517    3.011864    3.162288    3.134958
# std      1.227607    1.097478    1.032208    1.069450    1.122335    1.109440
# min      0.800000    0.900000    0.800000    0.900000    0.900000    0.900000
# 25%      2.600000    2.400000    2.200000    2.300000    2.400000    2.375000
# 50%      3.400000    3.100000    2.900000    2.900000    3.000000    3.000000
# 75%      4.100000    3.700000    3.600000    3.600000    3.800000    3.725000
# max      9.500000    7.900000    7.600000    7.900000    8.400000    7.900000
#
#           2008-07     2008-08     2008-09     2008-10  ...     7/31/2020  \
# count  472.000000  472.000000  472.000000  472.000000  ...  3.084200e+04
# mean     3.265466    3.479449    3.530085    3.701907  ...  2.316109e+05
# ...

# %%
print(Dataset.isnull().any())
# Out:
# index         False
# RegionType     True
# State          True
# FIPSCode       True
# 2008-01        True
#               ...
# 12/31/2020     True
# 1/31/2021      True
# 2/28/2021      True
# 3/31/2021      True
# 4/30/2021      True
# Length: 510, dtype: bool

# %%
Dataset = Dataset.fillna(0)

# %%
print(Dataset.isnull().sum())
# Out:
# index         0
# RegionType    0
# State         0
# FIPSCode      0
# 2008-01       0
#              ..
# 12/31/2020    0
# 1/31/2021     0
# 2/28/2021     0
# 3/31/2021     0
# 4/30/2021     0
# Length: 510, dtype: int64

# %%
print(Dataset.dtypes)
# Out:
# index          object
# RegionType     object
# State          object
# FIPSCode       object
# 2008-01       float64
#                ...
# 12/31/2020    float64
# 1/31/2021     float64
# 2/28/2021     float64
# 3/31/2021     float64
# 4/30/2021     float64
# Length: 510, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
correlation = Dataset.corr(method='pearson')
columns = correlation.nlargest(10, 'ENROLLMENT').index
columns
# Out:
# Index(['ENROLLMENT', 'POPULATION', 'NAICS_CODE', 'LATITUDE', 'Y', 'FT_TEACHER',
#        'OBJECTID', 'ZIP', 'COUNTYFIPS', 'NCESID'],
#       dtype='object')

# %%
correlation_map = np.corrcoef(Dataset[columns].values.T)
sns.set(font_scale=1.0)
heatmap = sns.heatmap(correlation_map, cbar=True, annot=True, square=True, fmt='.2f', yticklabels=columns.values, xticklabels=columns.values)

plt.show()

# %%
X = Dataset[columns]
Y = X['ENROLLMENT'].values
X = X.drop('ENROLLMENT', axis = 1).values

# %%
from sklearn import datasets
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split (X, Y, test_size = 0.20, random_state=42)

# %%
pipelines = []
pipelines.append(('ScaledLR', Pipeline([('Scaler', StandardScaler()),('LR',LinearRegression())])))
pipelines.append(('ScaledLASSO', Pipeline([('Scaler', StandardScaler()),('LASSO', Lasso())])))
pipelines.append(('ScaledEN', Pipeline([('Scaler', StandardScaler()),('EN', ElasticNet())])))
pipelines.append(('ScaledKNN', Pipeline([('Scaler', StandardScaler()),('KNN', KNeighborsRegressor())])))
pipelines.append(('ScaledCART', Pipeline([('Scaler', StandardScaler()),('CART', DecisionTreeRegressor())])))
pipelines.append(('ScaledGBM', Pipeline([('Scaler', StandardScaler()),('GBM', GradientBoostingRegressor())])))

# %%
results = []
names = []
for name, model in pipelines:
    kfold = KFold(n_splits=10, random_state=21)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='neg_mean_squared_error')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# C:\Users\louis\Anaconda3\envs\deeplearnenv\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# ScaledLR: -9779.916292 (868.364647)
# C:\Users\louis\Anaconda3\envs\deeplearnenv\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# ScaledLASSO: -9791.944200 (879.430939)
# C:\Users\louis\Anaconda3\envs\deeplearnenv\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# ...

# %% [markdown]
# # GBM has the lowest numbers so Gradient Boosting Regressor is the best model for this data

# %%
# GridSearchCV function

from sklearn.model_selection import GridSearchCV

scaler = StandardScaler().fit(X_train)
rescaledX = scaler.transform(X_train)
param_grid = dict(n_estimators=np.array([50,100,200,300,400]))
model = GradientBoostingRegressor(random_state=21)
kfold = KFold(n_splits=10, random_state=21)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_squared_error', cv=kfold)
grid_result = grid.fit(rescaledX, Y_train)

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# C:\Users\louis\Anaconda3\envs\deeplearnenv\lib\site-packages\sklearn\model_selection\_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# -6722.928485 (1212.525793) with: {'n_estimators': 50}
# -5132.023068 (890.435482) with: {'n_estimators': 100}
# -4120.055711 (758.405003) with: {'n_estimators': 200}
# -3737.527370 (758.229516) with: {'n_estimators': 300}
# -3519.791468 (785.581285) with: {'n_estimators': 400}
# Best: -3519.791468 using {'n_estimators': 400}

# %%
from sklearn.metrics import mean_squared_error

scaler = StandardScaler().fit(X_train)
rescaled_X_train = scaler.transform(X_train)
model = GradientBoostingRegressor(random_state=21, n_estimators=400)
model.fit(rescaled_X_train, Y_train)

# transform the validation dataset
rescaled_X_test = scaler.transform(X_test)
predictions = model.predict(rescaled_X_test)
print (mean_squared_error(Y_test, predictions))
# Out:
# 3762.0997940063135

# %%
compare = pd.DataFrame({'Prediction': predictions, 'Test Data' : Y_test})
compare.head(10)
# Out:
#     Prediction  Test Data
# 0   528.417385      519.0
# 1    -0.205167        0.0
# 2    -0.205167        0.0
# 3   654.638905      664.0
# 4  2033.569541     2033.0
# 5   146.961152      148.0
# 6    -0.205167        0.0
# 7    -0.205167        0.0
# 8   407.940196      399.0
# 9   272.028297      267.0

# %%
# actual_y_test = np.exp(Y_test)
# actual_predicted = np.exp(predictions)
diff = abs(actual_y_test - actual_predicted)

compare_actual = pd.DataFrame({'Test Data': actual_y_test, 'Predicted Enrollment' : actual_predicted, 'Difference' : diff})
# compare_actual = compare_actual.astype(int)
compare_actual.head(20)
# Out:
# C:\Users\louis\Anaconda3\envs\deeplearnenv\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in subtract
#   This is separate from the ipykernel package so we can avoid doing imports until
#         Test Data  Predicted Enrollment     Difference
# 0   2.505164e+225         3.081446e+229  3.081195e+229
# 1    1.000000e+00          8.145112e-01   1.854888e-01
# 2    1.000000e+00          8.145112e-01   1.854888e-01
# 3   2.352534e+288         2.023318e+284  2.352332e+288
# 4             inf                   inf            NaN
# 5    1.886181e+64          6.674480e+63   1.218733e+64
# 6    1.000000e+00          8.145112e-01   1.854888e-01
# 7    1.000000e+00          8.145112e-01   1.854888e-01
# 8   1.920871e+173         1.466142e+177  1.465949e+177
# 9   9.049543e+115         1.381619e+118  1.372569e+118
# 10   1.000000e+00          2.063676e-51   1.000000e+00
# 11  5.517990e+229         1.577982e+232  1.572464e+232
# ...

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 96 kB 2.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %%
unemploy_rate = pd.read_excel(
    Path("GeoFRED_Unemployment_Rate_by_County_Percent.xls"), header=1, index_col=2
)
unemploy_rate.head()
# Out:
#               Series ID           Region Name  2011 April  2011 May  \
# Region Code
# 45001        SCABBE1URN  Abbeville County, SC        11.8      12.1
# 22001        LAACAD0URN     Acadia Parish, LA         5.9       6.3
# 51001        VAACCO1URN   Accomack County, VA         8.0       7.7
# 16001        IDADAC1URN        Ada County, ID         7.3       6.8
# 40001        OKADAI1URN      Adair County, OK         8.0       8.5
#
#              2011 June  2011 July  2011 August  2011 September  2011 October  \
# Region Code
# 45001             13.1       13.1         12.8            12.0          11.6
# 22001              7.0        6.6          6.4             6.3           6.1
# 51001              7.8        8.0          8.2             7.9           7.6
# 16001              7.1        7.0          6.9             6.8           6.7
# 40001              8.8        8.8          8.1             8.0           8.1
#
# ...

# %%
unemploy_rate.describe()
# Out:
#         2011 April     2011 May    2011 June    2011 July  2011 August  \
# count  3141.000000  3141.000000  3141.000000  3141.000000  3141.000000
# mean      8.454027     8.447501     8.940274     8.867940     8.591882
# std       3.023178     3.004798     3.063138     3.166933     3.025700
# min       1.300000     1.400000     1.700000     1.300000     1.300000
# 25%       6.400000     6.400000     6.900000     6.700000     6.500000
# 50%       8.200000     8.300000     8.800000     8.800000     8.500000
# 75%      10.200000    10.200000    10.800000    10.700000    10.300000
# max      28.900000    28.500000    29.500000    32.300000    32.300000
#
#        2011 September  2011 October  2011 November  2011 December  \
# count     3141.000000   3141.000000    3141.000000    3141.000000
# mean         8.258930      8.006813       7.886183       8.147851
# std          2.916658      2.913308       2.928916       3.042966
# ...

# %%
March_2021 = unemploy_rate['2021 March']
March_2021
# Out:
# Region Code
# 45001     5.4
# 22001     5.7
# 51001     6.1
# 16001     3.5
# 40001     3.7
#          ...
# 4027     11.3
# 8125      4.2
# 48505    14.0
# 48507    15.0
# 46137     3.0
# Name: 2021 March, Length: 3141, dtype: float64

# %%
March_2021.describe()
# Out:
# count    3140.000000
# mean        5.394682
# std         2.106901
# min         1.100000
# 25%         4.000000
# 50%         5.100000
# 75%         6.500000
# max        20.000000
# Name: 2021 March, dtype: float64

# %%
March_2021.describe().plot()
# Out:
# <AxesSubplot:>

# %%
numbers_sorted =sorted(unemploy_rate['2021 March'])
numbers_sorted[:5]
# Out:
# [1.1, 1.2, 1.6, 1.9, 1.9]

# %%
numbers_reverse = sorted(March_2021, reverse=True)
numbers_reverse[:5]
# Out:
# [20.0, 18.5, 18.4, 17.6, 16.7]
